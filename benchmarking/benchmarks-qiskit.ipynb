# %% [markdown]
# ### QED-C Application-Oriented Benchmarks - Qiskit Version
# The notebook contains a suite of application-oriented benchmarks for the Qiskit API.
# Configure and run the cell below with the desired execution settings.
# Then execute the remaining cells, each containing one benchmark program.

# %%
from spa_benchmarking.qiskit import spa_benchmark

# %%
MIN_QUBITS=4
MAX_QUBITS=12
SEED=0
BACKEND_ID="qasm_simulator"
METHOD=1

# %% [markdown]
# ### AIM SPA VQE

# %% [markdown]
# #### No Noise

# %%
exec_options = {"noise_model": None}

spa_benchmark.run(min_qubits=MIN_QUBITS,
                  max_qubits=MAX_QUBITS,
                  seed=SEED, method=METHOD,
                  backend_id=BACKEND_ID,
                  exec_options=exec_options)
# Out:
# AIM SPA VQE Simulation (1) Benchmark Program - Qiskit
# ... execution starting at Nov 25, 2024 17:05:16 UTC
# ************
# Executing [3] circuits with n_qubits = 4
# ************
# Executing [3] circuits with n_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 25, 0.25
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 22, 0.286, 16.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.168, 0.177, 0.003 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.999, 0.999
#
# ************
# Executing [3] circuits with n_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 35, 0.246
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 31, 0.28, 28.0
# ...

# %% [markdown]
# #### Custom Noise Model, QV = 32

# %%
exec_options = {}
noise_model="QV32_noise_model.json" # select file with noise model parameters to import

spa_benchmark.run(min_qubits=MIN_QUBITS,
                  max_qubits=MAX_QUBITS,
                  seed=SEED, method=METHOD,
                  backend_id=BACKEND_ID,
                  exec_options=exec_options,
                  noise_model=noise_model)
# Out:
# AIM SPA VQE Simulation (1) Benchmark Program - Qiskit
# ... execution starting at Nov 25, 2024 17:05:20 UTC
# ************
# Executing [3] circuits with n_qubits = 4
# ************
# Executing [3] circuits with n_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 25, 0.25
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 22, 0.286, 16.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.019, 0.138, 0.004 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.697, 0.647
#
# ************
# Executing [3] circuits with n_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 35, 0.246
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 31, 0.28, 28.0
# ...

# %% [markdown]
# #### Custom Noise Model, QV = 2048

# %%
exec_options = {}
noise_model="QV2048_noise_model.json"  # select file with noise model parameters to import

spa_benchmark.run(min_qubits=MIN_QUBITS,
                  max_qubits=MAX_QUBITS,
                  seed=SEED, method=METHOD,
                  backend_id=BACKEND_ID,
                  exec_options=exec_options,
                  noise_model=noise_model)
# Out:
# AIM SPA VQE Simulation (1) Benchmark Program - Qiskit
# ... execution starting at Nov 25, 2024 17:05:27 UTC
# ************
# Executing [3] circuits with n_qubits = 4
# ************
# Executing [3] circuits with n_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 25, 0.25
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 22, 0.286, 16.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.018, 0.136, 0.002 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.942, 0.932
#
# ************
# Executing [3] circuits with n_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 35, 0.246
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 31, 0.28, 28.0
# ...
